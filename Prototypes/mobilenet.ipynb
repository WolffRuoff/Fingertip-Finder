# %%
import torch
import gc
import torchvision.models as models
import torch.nn as nn

import dataloader
import trainer
import evaluator
import visualizer

# %% [markdown]
# ## Main Functions

# %% [markdown]
# Auto-reload files imported to the notebook

# %%
# %load_ext autoreload
# %autoreload 2

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device:', device)
# Out:
# Device: cpu

# %%
TILE_HEIGHT, TILE_WIDTH = 80, 80

# %% [markdown]
# For torch dataloader to use num_workers > 0, it relies on python multiprocessing, which in windows have deadlock issues, unless the instantiation is in a .py module and the code that invokes it is wrapped inside a \__main__ section.
# https://github.com/pytorch/pytorch/issues/51344

# %%
if __name__ == '__main__':
    loader_train, loader_val, loader_test = dataloader.main(TILE_HEIGHT, TILE_WIDTH, batch_size=10, num_workers=3)

# %%
# Free cuda memory
# Reference: https://discuss.pytorch.org/t/how-to-debug-causes-of-gpu-memory-leaks/6741/13
def freemem():
    for obj in gc.get_objects():
        if torch.is_tensor(obj) and torch.is_tensor(obj.data):
            del obj
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

# %% [markdown]
# ## Mobilenet

# %% [markdown]
# Here we import the mobilenet model with pretrained weights. This gives us some good starting weights so that we don't have to train the model from scratch.

# %%
mobilenet = models.mobilenet_v2(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /Users/ethanruoff/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100.0%

# %% [markdown]
# From there, we replace the last layer to work with the tiles format rather than mobilenet's standard classification. Lastly, we freeze all of the layers except for the newly added layer so that it can be trained individually

# %%
mobilenet.classifier[-1] = nn.Linear(1280, TILE_HEIGHT*TILE_WIDTH)
print(mobilenet.classifier)
# Out:
# Sequential(
#   (0): Dropout(p=0.2, inplace=False)
#   (1): Linear(in_features=1280, out_features=6400, bias=True)
# )

# %% [markdown]
# ##### NOTE: If you want to load the saved model then skip then section and run from the Visualize Model section

# %%
for param in mobilenet.parameters():
    param.require_grad = False
mobilenet.classifier[-1].requires_grad_(True)

# %% [markdown]
# Now let's train the model!

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Device:', device)
mobilenet = mobilenet.to(device)
trainer.train(mobilenet, loader_train, loader_val, lr=1e-4, device=device, num_epochs=100, patience=10)

# %% [markdown]
# Unfreeze the layers and train with the fully unfrozen model

# %%
for param in mobilenet.parameters():
    param.require_grad = True
trainer.train(mobilenet, loader_train, loader_val, lr=1e-4, device=device, num_epochs=100, patience=10)

torch.save(mobilenet.state_dict(), 'saved_models/mobilenet.model')
# Out:
# Training epoch 1 batch 150/300, train loss = 0.022398, train acc = 0.991984, recall = 0.268441, precision = 0.680235
# validation metrics at epoch 1 batch 150: val loss = 0.026818, val acc = 0.991151, val recall = 0.198995, val precision = 0.587663
# Training epoch 1 batch 300/300, train loss = 0.022447, train acc = 0.991871, recall = 0.272744, precision = 0.669582
# validation metrics at epoch 1 batch 300: val loss = 0.027160, val acc = 0.991023, val recall = 0.237719, val precision = 0.555245
# current_patience = 9
# ================================================================================
# Epoch 1/100 train loss = 0.022447, train acc = 0.991871, val loss = 0.027160, val acc = 0.991023
# Training epoch 2 batch 150/300, train loss = 0.021685, train acc = 0.992127, recall = 0.275347, precision = 0.682170
# validation metrics at epoch 2 batch 150: val loss = 0.027139, val acc = 0.990469, val recall = 0.293604, val precision = 0.489054
# current_patience = 8
# Training epoch 2 batch 300/300, train loss = 0.022121, train acc = 0.992022, recall = 0.283036, precision = 0.684643
# validation metrics at epoch 2 batch 300: val loss = 0.026611, val acc = 0.991136, val recall = 0.193520, val precision = 0.577864
# ================================================================================
# Epoch 2/100 train loss = 0.022121, train acc = 0.992022, val loss = 0.026611, val acc = 0.991136
# Training epoch 3 batch 150/300, train loss = 0.021706, train acc = 0.992144, recall = 0.292039, precision = 0.693918
# validation metrics at epoch 3 batch 150: val loss = 0.026534, val acc = 0.990932, val recall = 0.224571, val precision = 0.533082
# Training epoch 3 batch 300/300, train loss = 0.021890, train acc = 0.992045, recall = 0.289762, precision = 0.683285
# validation metrics at epoch 3 batch 300: val loss = 0.026243, val acc = 0.991217, val recall = 0.183191, val precision = 0.602441
# ================================================================================
# Epoch 3/100 train loss = 0.021890, train acc = 0.992045, val loss = 0.026243, val acc = 0.991217
# Training epoch 4 batch 150/300, train loss = 0.021387, train acc = 0.992172, recall = 0.307976, precision = 0.694120
# validation metrics at epoch 4 batch 150: val loss = 0.026592, val acc = 0.990966, val recall = 0.240762, val precision = 0.534827
# current_patience = 9
# Training epoch 4 batch 300/300, train loss = 0.021620, train acc = 0.992113, recall = 0.304127, precision = 0.685278
# validation metrics at epoch 4 batch 300: val loss = 0.026187, val acc = 0.991185, val recall = 0.198938, val precision = 0.591547
# ================================================================================
# Epoch 4/100 train loss = 0.021620, train acc = 0.992113, val loss = 0.026187, val acc = 0.991185
# Training epoch 5 batch 150/300, train loss = 0.021271, train acc = 0.992133, recall = 0.309571, precision = 0.685807
# validation metrics at epoch 5 batch 150: val loss = 0.027262, val acc = 0.990719, val recall = 0.223768, val precision = 0.522541
# current_patience = 9
# Training epoch 5 batch 300/300, train loss = 0.021434, train acc = 0.992157, recall = 0.309589, precision = 0.684291
# validation metrics at epoch 5 batch 300: val loss = 0.026997, val acc = 0.991298, val recall = 0.164403, val precision = 0.651887
# current_patience = 8
# ================================================================================
# Epoch 5/100 train loss = 0.021434, train acc = 0.992157, val loss = 0.026997, val acc = 0.991298
# Training epoch 6 batch 150/300, train loss = 0.021550, train acc = 0.992087, recall = 0.304665, precision = 0.688798
# validation metrics at epoch 6 batch 150: val loss = 0.027012, val acc = 0.991162, val recall = 0.202788, val precision = 0.584315
# current_patience = 7
# Training epoch 6 batch 300/300, train loss = 0.021328, train acc = 0.992199, recall = 0.310502, precision = 0.690822
# validation metrics at epoch 6 batch 300: val loss = 0.026576, val acc = 0.990838, val recall = 0.234555, val precision = 0.520200
# current_patience = 6
# ================================================================================
# Epoch 6/100 train loss = 0.021328, train acc = 0.992199, val loss = 0.026576, val acc = 0.990838
# Training epoch 7 batch 150/300, train loss = 0.020595, train acc = 0.992364, recall = 0.323507, precision = 0.692117
# validation metrics at epoch 7 batch 150: val loss = 0.027788, val acc = 0.991133, val recall = 0.183212, val precision = 0.589412
# current_patience = 5
# Training epoch 7 batch 300/300, train loss = 0.021197, train acc = 0.992217, recall = 0.317512, precision = 0.691198
# validation metrics at epoch 7 batch 300: val loss = 0.027210, val acc = 0.991186, val recall = 0.194178, val precision = 0.594447
# current_patience = 4
# ================================================================================
# Epoch 7/100 train loss = 0.021197, train acc = 0.992217, val loss = 0.027210, val acc = 0.991186
# Training epoch 8 batch 150/300, train loss = 0.020539, train acc = 0.992515, recall = 0.340288, precision = 0.713346
# validation metrics at epoch 8 batch 150: val loss = 0.026790, val acc = 0.991059, val recall = 0.219912, val precision = 0.560980
# current_patience = 3
# Training epoch 8 batch 300/300, train loss = 0.020885, train acc = 0.992353, recall = 0.331968, precision = 0.702050
# validation metrics at epoch 8 batch 300: val loss = 0.026945, val acc = 0.990757, val recall = 0.224054, val precision = 0.516929
# current_patience = 2
# ================================================================================
# Epoch 8/100 train loss = 0.020885, train acc = 0.992353, val loss = 0.026945, val acc = 0.990757
# Training epoch 9 batch 150/300, train loss = 0.020512, train acc = 0.992372, recall = 0.348975, precision = 0.705516
# validation metrics at epoch 9 batch 150: val loss = 0.027318, val acc = 0.991200, val recall = 0.233886, val precision = 0.581780
# current_patience = 1
# Training epoch 9 batch 300/300, train loss = 0.020796, train acc = 0.992362, recall = 0.337921, precision = 0.698282
# validation metrics at epoch 9 batch 300: val loss = 0.026174, val acc = 0.990966, val recall = 0.235292, val precision = 0.542809
# ================================================================================
# Epoch 9/100 train loss = 0.020796, train acc = 0.992362, val loss = 0.026174, val acc = 0.990966
# Training epoch 10 batch 150/300, train loss = 0.020820, train acc = 0.992274, recall = 0.327679, precision = 0.695117
# validation metrics at epoch 10 batch 150: val loss = 0.026822, val acc = 0.990965, val recall = 0.235911, val precision = 0.533980
# current_patience = 9
# Training epoch 10 batch 300/300, train loss = 0.020614, train acc = 0.992343, recall = 0.333914, precision = 0.694742
# validation metrics at epoch 10 batch 300: val loss = 0.026937, val acc = 0.990971, val recall = 0.231208, val precision = 0.538603
# current_patience = 8
# ================================================================================
# Epoch 10/100 train loss = 0.020614, train acc = 0.992343, val loss = 0.026937, val acc = 0.990971
# Training epoch 11 batch 150/300, train loss = 0.019895, train acc = 0.992573, recall = 0.361036, precision = 0.704408
# validation metrics at epoch 11 batch 150: val loss = 0.027332, val acc = 0.990993, val recall = 0.235130, val precision = 0.547247
# current_patience = 7
# Training epoch 11 batch 300/300, train loss = 0.020241, train acc = 0.992442, recall = 0.350762, precision = 0.698856
# validation metrics at epoch 11 batch 300: val loss = 0.026966, val acc = 0.991089, val recall = 0.213607, val precision = 0.578937
# current_patience = 6
# ================================================================================
# Epoch 11/100 train loss = 0.020241, train acc = 0.992442, val loss = 0.026966, val acc = 0.991089
# Training epoch 12 batch 150/300, train loss = 0.020021, train acc = 0.992484, recall = 0.354802, precision = 0.700755
# validation metrics at epoch 12 batch 150: val loss = 0.026822, val acc = 0.990843, val recall = 0.262825, val precision = 0.529382
# current_patience = 5
# Training epoch 12 batch 300/300, train loss = 0.020226, train acc = 0.992479, recall = 0.351923, precision = 0.704692
# validation metrics at epoch 12 batch 300: val loss = 0.026458, val acc = 0.990980, val recall = 0.277005, val precision = 0.531477
# current_patience = 4
# ================================================================================
# Epoch 12/100 train loss = 0.020226, train acc = 0.992479, val loss = 0.026458, val acc = 0.990980
# Training epoch 13 batch 150/300, train loss = 0.019957, train acc = 0.992509, recall = 0.363640, precision = 0.704800
# validation metrics at epoch 13 batch 150: val loss = 0.026762, val acc = 0.991159, val recall = 0.203322, val precision = 0.597355
# current_patience = 3
# Training epoch 13 batch 300/300, train loss = 0.020135, train acc = 0.992487, recall = 0.357039, precision = 0.700942
# validation metrics at epoch 13 batch 300: val loss = 0.026815, val acc = 0.990848, val recall = 0.273521, val precision = 0.525644
# current_patience = 2
# ================================================================================
# Epoch 13/100 train loss = 0.020135, train acc = 0.992487, val loss = 0.026815, val acc = 0.990848
# Training epoch 14 batch 150/300, train loss = 0.020170, train acc = 0.992520, recall = 0.362962, precision = 0.713901
# validation metrics at epoch 14 batch 150: val loss = 0.027648, val acc = 0.991066, val recall = 0.205759, val precision = 0.560681
# current_patience = 1
# Training epoch 14 batch 300/300, train loss = 0.019932, train acc = 0.992563, recall = 0.359322, precision = 0.711426
# validation metrics at epoch 14 batch 300: val loss = 0.027215, val acc = 0.990969, val recall = 0.259879, val precision = 0.531797
# current_patience = 0
#
# stopping early after no validation accuracy improvement in 1500 steps
# ([0.02681813485920429,
#   0.027160032615065575,
#   0.02713856615126133,
#   0.026610926911234855,
#   0.026533921994268895,
#   0.026243202947080137,
#   0.026591709330677987,
#   0.026186857335269452,
#   0.027262344174087048,
#   0.02699666704982519,
#   0.027012421227991582,
#   0.026575788371264935,
#   0.027787906117737293,
#   0.027210327237844466,
#   0.026790320053696633,
#   0.02694450818002224,
#   0.027317871786653996,
#   0.026173584945499897,
#   0.026822077631950377,
#   0.026936701014637947,
#   0.027331936284899713,
#   0.026965696178376675,
#   0.026821876652538778,
#   0.026457601748406886,
#   0.026762000881135464,
#   0.026815281249582767,
#   0.027647956758737564,
#   0.027214638888835907],
#  [0.9911505949497222,
#   0.9910232031345367,
#   0.9904693496227265,
#   0.9911358773708343,
#   0.9909319365024567,
#   0.9912172901630402,
#   0.9909661734104156,
#   0.9911846220493317,
#   0.9907194304466248,
#   0.9912977480888366,
#   0.9911615753173828,
#   0.9908379542827607,
#   0.9911326575279236,
#   0.9911859083175659,
#   0.991059398651123,
#   0.9907571184635162,
#   0.9911998200416565,
#   0.9909659218788147,
#   0.9909649920463562,
#   0.9909711074829102,
#   0.9909927475452424,
#   0.9910885322093964,
#   0.9908433818817138,
#   0.9909795999526978,
#   0.9911589729785919,
#   0.990847886800766,
#   0.9910664820671081,
#   0.9909693789482117])

# %% [markdown]
# ## Model Visualizations

# %% [markdown]
# Load the model if you dont want to train it

# %%
mobilenet.load_state_dict(torch.load('saved_models/mobilenet.model', map_location=torch.device(device)))
# Out:
# <All keys matched successfully>

# %%
visualizer.visualize_model_output(loader_test, mobilenet, 10, TILE_HEIGHT=80, TILE_WIDTH=80, device=device)
# Out:
# torch.Size([10, 3, 48, 80, 80]) torch.Size([10, 3, 48, 80, 80])
# Accuracy = 98.74922037124634%
# Precision = 3.0976677313447%
# Recall = 1.335952803492546%
